# %%
from postgresql_query import make_query

# %%
df = make_query("queries/test.sql", query_file=True)
# Out:
# Starting query
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Grecia\Desktop\Juan\2023.09_QuerySUBE\source\test.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Grecia/Desktop/Juan/2023.09_QuerySUBE/source/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = make_query("queries/test.sql", query_file=True)
#
# File c:\Users\Grecia\Desktop\Juan\2023.09_QuerySUBE\source\postgresql_query.py:42, in make_query(query, query_file, dest_filename, save)
#      39     query_reader = open(main_path / f"source/{query}", "r")
#      40     query = query_reader.read()
# ---> 42 df_query = pd.read_sql_query(query, engine)
#      44 if save:
#      45     print("Saving result\n")
#
# ...

# %%
df.head()
# Out:
#    codigoentidad  idlinea            nrochip  nrotarjeta  codigocontrato  \
# 0            542     3594  40553674899662340  1848067281             621
# 1            542     3592  40556236707449092  1850789787             719
# 2            543     3605  36132070758178052  1840802135             602
# 3            543     3615  40553674891727364  1848988565             749
# 4            543     3615  40553024872073732  1847970539             602
#
#   secuencia_tarjeta            fechatrx  monto   saldo  valor_tarifa  ...  \
# 0                71 2023-08-15 06:37:42   54.0   57.50         120.0  ...
# 1                43 2023-08-15 16:30:31    0.0  272.32         120.0  ...
# 2               299 2023-08-15 10:35:02  120.0  184.62         120.0  ...
# 3                41 2023-08-15 13:35:46    0.0  785.94         120.0  ...
# 4                17 2023-08-15 13:38:09    0.0  873.64         120.0  ...
#
#    longitude  latitude velocity  distance  status  c_control_point  \
# ...
